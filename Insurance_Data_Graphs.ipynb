# %%
# GENDER VS INSURANCE CHARGES

# %%
plt.figure()
sns.boxplot(x='sex', y='charges in INR', data=df)
plt.title('Charges in INR by Gender')
plt.show()

# %%
# AGE VS INSURANCE CHARGES

# %%
plt.figure()
sns.scatterplot(x='age', y='charges in INR', data=df)
plt.title('Age vs Charges in INR')
plt.show()

# %%
#BMI VS INSURANCE CHARGES

# %%
plt.figure()
sns.scatterplot(x='bmi', y='charges in INR', data=df)
plt.title('BMI vs Charges in INR')
plt.show()

# %%
# INSURANCE CHARGES : SMOKER VS NON SMOKER

# %%
plt.figure()
sns.boxplot(x='smoker', y='charges in INR', data=df)
plt.title('Charges in INR: Smoker vs Non Smoker')
plt.show()

# %%
#INSURANCE CHARGES BY REGION

# %%
plt.figure()
sns.scatterplot(x='children', y='charges in INR', data=df)
plt.title('Children vs Charges in INR')
plt.show()

# %%
#DEPENDENT VS INSURANCE CHARGES

# %%
plt.figure()
sns.boxplot(x='region', y='charges in INR', data=df)
plt.title('Charges in INR by Region')
plt.show()

# %%
#CORRELATION HEATMAP

# %%
plt.figure()
sns.histplot(x='charges in INR', data=df)
plt.title('Distribution of Charges in INR')
plt.show()
